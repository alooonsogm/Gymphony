-- %% [markdown]
-- # [Gymphony]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Gymphony]    Script Date: 25/02/2026 17:16:31 ******/
CREATE DATABASE [Gymphony]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ProyectoIndividual', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.DEVELOPER\MSSQL\DATA\ProyectoIndividual.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ProyectoIndividual_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.DEVELOPER\MSSQL\DATA\ProyectoIndividual_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Gymphony] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Gymphony].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Gymphony] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Gymphony] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Gymphony] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Gymphony] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Gymphony] SET ARITHABORT OFF 
GO
ALTER DATABASE [Gymphony] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Gymphony] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Gymphony] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Gymphony] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Gymphony] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Gymphony] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Gymphony] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Gymphony] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Gymphony] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Gymphony] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Gymphony] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Gymphony] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Gymphony] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Gymphony] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Gymphony] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Gymphony] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Gymphony] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Gymphony] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Gymphony] SET  MULTI_USER 
GO
ALTER DATABASE [Gymphony] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Gymphony] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Gymphony] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Gymphony] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Gymphony] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Gymphony] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Gymphony] SET QUERY_STORE = ON
GO
ALTER DATABASE [Gymphony] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Afiliaciones]

-- %%
USE [Gymphony]
GO

-- %%
/****** Object:  Table [dbo].[Afiliaciones]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Afiliaciones](
	[Id] [int] NOT NULL,
	[ClienteId] [int] NOT NULL,
	[FechaAlta] [date] NOT NULL,
	[FechaBaja] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clases]

-- %%
/****** Object:  Table [dbo].[Clases]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clases](
	[Id] [int] NOT NULL,
	[Nombre] [nvarchar](50) NULL,
	[Description] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HorarioEmpleados]

-- %%
/****** Object:  Table [dbo].[HorarioEmpleados]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HorarioEmpleados](
	[Id] [int] NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[DiaSemana] [int] NOT NULL,
	[HoraInicio] [time](7) NOT NULL,
	[HoraFin] [time](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RegistroAforo]

-- %%
/****** Object:  Table [dbo].[RegistroAforo]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RegistroAforo](
	[Id] [int] NOT NULL,
	[ClienteId] [int] NOT NULL,
	[HoraEntrada] [datetime] NOT NULL,
	[HoraSalida] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReservaSesiones]

-- %%
/****** Object:  Table [dbo].[ReservaSesiones]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReservaSesiones](
	[Id] [int] NOT NULL,
	[SesionId] [int] NOT NULL,
	[ClienteId] [int] NOT NULL,
	[HoraReserva] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] NOT NULL,
	[Nombre] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salas]

-- %%
/****** Object:  Table [dbo].[Salas]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salas](
	[Id] [int] NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[CapacidadMaxima] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SeguridadUsuarios]

-- %%
/****** Object:  Table [dbo].[SeguridadUsuarios]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SeguridadUsuarios](
	[Id] [int] NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[PasswordHash] [varbinary](max) NOT NULL,
	[Salt] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sesiones]

-- %%
/****** Object:  Table [dbo].[Sesiones]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sesiones](
	[Id] [int] NOT NULL,
	[ClaseId] [int] NOT NULL,
	[EntrenadorId] [int] NOT NULL,
	[SalaId] [int] NOT NULL,
	[Fecha] [date] NOT NULL,
	[HoraInicio] [time](7) NOT NULL,
	[HoraFin] [time](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 25/02/2026 17:16:32 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id] [int] NOT NULL,
	[RoleId] [int] NOT NULL,
	[Email] [nvarchar](150) NULL,
	[Password] [nvarchar](255) NULL,
	[Nombre] [nvarchar](100) NULL,
	[Apellidos] [nvarchar](100) NULL,
	[Telefono] [nvarchar](50) NULL,
	[FechaNacimiento] [date] NULL,
	[DNI] [nvarchar](20) NULL,
	[RutaFoto] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Afiliaciones]

-- %%
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (1, 2, CAST(N'2023-01-15' AS Date), CAST(N'2023-09-01' AS Date))
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (2, 3, CAST(N'2023-06-01' AS Date), NULL)
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (3, 4, CAST(N'2022-03-10' AS Date), CAST(N'2022-11-30' AS Date))
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (4, 4, CAST(N'2023-10-01' AS Date), NULL)
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (5, 5, CAST(N'2024-02-01' AS Date), NULL)
INSERT [dbo].[Afiliaciones] ([Id], [ClienteId], [FechaAlta], [FechaBaja]) VALUES (6, 6, CAST(N'2024-01-10' AS Date), CAST(N'2024-02-10' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Clases]

-- %%
INSERT [dbo].[Clases] ([Id], [Nombre], [Description]) VALUES (1, N'Spinning', N'Clase de alta intensidad en bicicleta estática con música.')
INSERT [dbo].[Clases] ([Id], [Nombre], [Description]) VALUES (2, N'Yoga', N'Sesión de relajación, flexibilidad y control postural.')
INSERT [dbo].[Clases] ([Id], [Nombre], [Description]) VALUES (3, N'CrossFit', N'Entrenamiento funcional de alta intensidad.')
INSERT [dbo].[Clases] ([Id], [Nombre], [Description]) VALUES (4, N'Pilates', N'Mejora del core, postura y fuerza corporal suave.')
GO

-- %% [markdown]
-- # [dbo].[HorarioEmpleados]

-- %%
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (1, 7, 1, CAST(N'09:00:00' AS Time), CAST(N'15:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (2, 7, 2, CAST(N'09:00:00' AS Time), CAST(N'15:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (3, 7, 3, CAST(N'09:00:00' AS Time), CAST(N'15:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (4, 7, 4, CAST(N'09:00:00' AS Time), CAST(N'15:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (5, 7, 5, CAST(N'09:00:00' AS Time), CAST(N'15:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (6, 8, 1, CAST(N'15:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (7, 8, 2, CAST(N'15:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (8, 8, 3, CAST(N'15:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (9, 8, 4, CAST(N'15:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (10, 8, 5, CAST(N'15:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (11, 9, 6, CAST(N'09:00:00' AS Time), CAST(N'21:00:00' AS Time))
INSERT [dbo].[HorarioEmpleados] ([Id], [UsuarioId], [DiaSemana], [HoraInicio], [HoraFin]) VALUES (12, 9, 7, CAST(N'09:00:00' AS Time), CAST(N'21:00:00' AS Time))
GO

-- %% [markdown]
-- # [dbo].[RegistroAforo]

-- %%
INSERT [dbo].[RegistroAforo] ([Id], [ClienteId], [HoraEntrada], [HoraSalida]) VALUES (1, 3, CAST(N'2026-02-25T09:00:00.000' AS DateTime), CAST(N'2026-02-25T10:30:00.000' AS DateTime))
INSERT [dbo].[RegistroAforo] ([Id], [ClienteId], [HoraEntrada], [HoraSalida]) VALUES (2, 4, CAST(N'2026-02-24T18:15:00.000' AS DateTime), CAST(N'2026-02-24T19:45:00.000' AS DateTime))
INSERT [dbo].[RegistroAforo] ([Id], [ClienteId], [HoraEntrada], [HoraSalida]) VALUES (3, 5, CAST(N'2026-02-24T14:00:00.000' AS DateTime), CAST(N'2026-02-24T15:00:00.000' AS DateTime))
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
INSERT [dbo].[Roles] ([Id], [Nombre]) VALUES (1, N'Admin')
INSERT [dbo].[Roles] ([Id], [Nombre]) VALUES (2, N'Cliente')
INSERT [dbo].[Roles] ([Id], [Nombre]) VALUES (3, N'Entrenador')
GO

-- %% [markdown]
-- # [dbo].[Salas]

-- %%
INSERT [dbo].[Salas] ([Id], [Nombre], [CapacidadMaxima]) VALUES (1, N'Sala Ciclo', 30)
INSERT [dbo].[Salas] ([Id], [Nombre], [CapacidadMaxima]) VALUES (2, N'Sala Zen', 20)
INSERT [dbo].[Salas] ([Id], [Nombre], [CapacidadMaxima]) VALUES (3, N'Box Principal', 40)
INSERT [dbo].[Salas] ([Id], [Nombre], [CapacidadMaxima]) VALUES (4, N'Sala Polivalente', 25)
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (1, 1, N'12345', N'admin@gmail.com', N'Admin', N'Admin', N'1111-2222-3333', CAST(N'1985-05-10' AS Date), N'11111111A', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (2, 2, N'12345', N'laura@gmail.com', N'Laura', N'García', N'611000001', CAST(N'1990-08-20' AS Date), N'22222222B', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (3, 2, N'12345', N'alonso@gmail.com', N'Alonso', N'Garcia', N'611000002', CAST(N'1995-11-05' AS Date), N'33333333C', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (4, 2, N'12345', N'ana@gmail.com', N'Ana', N'Martínez', N'611000003', CAST(N'1988-02-15' AS Date), N'44444444D', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (5, 2, N'12345', N'javier@gmail.com', N'Javier', N'Fernández', N'611000004', CAST(N'2001-07-30' AS Date), N'55555555E', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (6, 2, N'12345', N'sofia@gmail.com', N'Sofía', N'Ruiz', N'611000005', CAST(N'1992-09-12' AS Date), N'66666666F', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (7, 3, N'12345', N'marcosTrainer@gmail.com', N'Marcos', N'Vidal', N'622000001', CAST(N'1989-04-25' AS Date), N'77777777G', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (8, 3, N'12345', N'elenaTrainer@gmail.com', N'Elena', N'Sánchez', N'622000002', CAST(N'1993-12-10' AS Date), N'88888888H', NULL)
INSERT [dbo].[Usuarios] ([Id], [RoleId], [Email], [Password], [Nombre], [Apellidos], [Telefono], [FechaNacimiento], [DNI], [RutaFoto]) VALUES (9, 3, N'12345', N'pabloTrainer@gmail.com', N'Pablo', N'Díaz', N'622000003', CAST(N'1996-01-22' AS Date), N'99999999J', NULL)
GO

-- %% [markdown]
-- # [FK_Afiliaciones_Usuarios]

-- %%
ALTER TABLE [dbo].[Afiliaciones]  WITH CHECK ADD  CONSTRAINT [FK_Afiliaciones_Usuarios] FOREIGN KEY([ClienteId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
ALTER TABLE [dbo].[Afiliaciones] CHECK CONSTRAINT [FK_Afiliaciones_Usuarios]
GO

-- %% [markdown]
-- # [FK_Horario_Usuarios]

-- %%
ALTER TABLE [dbo].[HorarioEmpleados]  WITH CHECK ADD  CONSTRAINT [FK_Horario_Usuarios] FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
ALTER TABLE [dbo].[HorarioEmpleados] CHECK CONSTRAINT [FK_Horario_Usuarios]
GO

-- %% [markdown]
-- # [FK_Attendance_Users]

-- %%
ALTER TABLE [dbo].[RegistroAforo]  WITH CHECK ADD  CONSTRAINT [FK_Attendance_Users] FOREIGN KEY([ClienteId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
ALTER TABLE [dbo].[RegistroAforo] CHECK CONSTRAINT [FK_Attendance_Users]
GO

-- %% [markdown]
-- # [fk_booking_client]

-- %%
ALTER TABLE [dbo].[ReservaSesiones]  WITH CHECK ADD  CONSTRAINT [fk_booking_client] FOREIGN KEY([ClienteId])
REFERENCES [dbo].[Usuarios] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ReservaSesiones] CHECK CONSTRAINT [fk_booking_client]
GO

-- %% [markdown]
-- # [fk_booking_session]

-- %%
ALTER TABLE [dbo].[ReservaSesiones]  WITH CHECK ADD  CONSTRAINT [fk_booking_session] FOREIGN KEY([SesionId])
REFERENCES [dbo].[Sesiones] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[ReservaSesiones] CHECK CONSTRAINT [fk_booking_session]
GO

-- %% [markdown]
-- # [FK_Seguridad_Usuarios]

-- %%
ALTER TABLE [dbo].[SeguridadUsuarios]  WITH CHECK ADD  CONSTRAINT [FK_Seguridad_Usuarios] FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
ALTER TABLE [dbo].[SeguridadUsuarios] CHECK CONSTRAINT [FK_Seguridad_Usuarios]
GO

-- %% [markdown]
-- # [FK_Sesiones_Salas]

-- %%
ALTER TABLE [dbo].[Sesiones]  WITH CHECK ADD  CONSTRAINT [FK_Sesiones_Salas] FOREIGN KEY([SalaId])
REFERENCES [dbo].[Salas] ([Id])
GO
ALTER TABLE [dbo].[Sesiones] CHECK CONSTRAINT [FK_Sesiones_Salas]
GO

-- %% [markdown]
-- # [fk_session_class]

-- %%
ALTER TABLE [dbo].[Sesiones]  WITH CHECK ADD  CONSTRAINT [fk_session_class] FOREIGN KEY([ClaseId])
REFERENCES [dbo].[Clases] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Sesiones] CHECK CONSTRAINT [fk_session_class]
GO

-- %% [markdown]
-- # [fk_session_trainer]

-- %%
ALTER TABLE [dbo].[Sesiones]  WITH CHECK ADD  CONSTRAINT [fk_session_trainer] FOREIGN KEY([EntrenadorId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
ALTER TABLE [dbo].[Sesiones] CHECK CONSTRAINT [fk_session_trainer]
GO

-- %% [markdown]
-- # [fk_usuariO_role]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [fk_usuariO_role] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [fk_usuariO_role]
GO

-- %% [markdown]
-- # [Gymphony]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Gymphony] SET  READ_WRITE 
GO
